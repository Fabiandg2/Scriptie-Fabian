# %%
import pandas as pd
import json
import os
import random
import seaborn as sns
import matplotlib.pyplot as plt
from pydriller import Repository

# Zorgt dat grafieken direct zichtbaar zijn
# %matplotlib inline

# %%
FOLDER_PATH = os.path.join('Databestanden', 'npm')
ECOSYSTEM_NAME = "Node.js (npm)"

print(f"--- START MINING VOOR: {ECOSYSTEM_NAME} ---")
print(f"Map: {FOLDER_PATH}")
# Out:
# --- START MINING VOOR: Node.js (npm) ---
# Map: Databestanden/npm

# %%
def score_to_group(score):
    if score >= 9.0: return 'Critical'
    elif score >= 7.0: return 'High'
    elif score >= 4.0: return 'Medium'
    else: return 'Low'

def get_severity_group(entry, entry_id=""):
    """
    Bepaalt severity. Geeft 'None' terug voor Malware, 
    omdat we geen malware willen minen.
    """
    # 1. Malware negeren voor Mining
    if entry_id.startswith('MAL-'):
        return None 

    severity_str = None
    raw_sev = entry.get('severity')

    # 2. Check 'database_specific' (Cruciaal voor npm GHSA!)
    if 'database_specific' in entry:
        severity_str = entry['database_specific'].get('severity')

    # 3. Check root string
    if not severity_str and isinstance(raw_sev, str):
        severity_str = raw_sev

    # 4. Categoriseren op tekst
    if severity_str:
        s = severity_str.upper()
        if 'CRITICAL' in s: return 'Critical'
        if 'HIGH' in s: return 'High'
        if 'MODERATE' in s or 'MEDIUM' in s: return 'Medium'
        if 'LOW' in s: return 'Low'
    
    # 5. Categoriseren op score (lijst of getal)
    if isinstance(raw_sev, list):
        for item in raw_sev:
            if isinstance(item, dict) and isinstance(item.get('score'), (int, float)):
                return score_to_group(float(item['score']))
            if isinstance(item, dict) and item.get('type') in ['CVSS_V3', 'CVSS_V31']:
                 try: return score_to_group(float(item.get('score')))
                 except: pass

    if isinstance(raw_sev, (int, float)):
        return score_to_group(float(raw_sev))

    return None

# %%
candidates = {'Low': [], 'Medium': [], 'High': [], 'Critical': []}

if not os.path.exists(FOLDER_PATH):
    print(f"FOUT: Map niet gevonden: {FOLDER_PATH}")
else:
    files = [f for f in os.listdir(FOLDER_PATH) if f.endswith('.json')]
    total_files = len(files)
    print(f"Scannen van {total_files} bestanden op GitHub links...")

    counter = 0
    found_count = 0

    for filename in files:
        counter += 1
        if counter % 10000 == 0: print(f"   Gescand: {counter}/{total_files}...")

        if filename.startswith('MAL-'): continue

        try:
            with open(os.path.join(FOLDER_PATH, filename), 'r', encoding='utf-8') as f:
                entry = json.load(f)
                
                group = get_severity_group(entry, entry.get('id', filename))
                
                if group and 'references' in entry:
                    for ref in entry['references']:
                        url = ref.get('url', '')
                        # We zoeken specifieke commit links
                        if 'github.com' in url and '/commit/' in url:
                            candidates[group].append(url)
                            found_count += 1
                            break 
        except: continue

    print("-" * 30)
    print(f"Totaal GitHub fix-commits gevonden: {found_count}")
    for g, urls in candidates.items():
        print(f"  {g}: {len(urls)}")
# Out:
# Scannen van 213504 bestanden op GitHub links...
#    Gescand: 10000/213504...
#    Gescand: 20000/213504...
#    Gescand: 30000/213504...
#    Gescand: 40000/213504...
#    Gescand: 50000/213504...
#    Gescand: 60000/213504...
#    Gescand: 70000/213504...
#    Gescand: 80000/213504...
#    Gescand: 90000/213504...
#    Gescand: 100000/213504...
#    Gescand: 110000/213504...
#    Gescand: 120000/213504...
#    Gescand: 130000/213504...
#    Gescand: 140000/213504...
#    Gescand: 150000/213504...
#    Gescand: 160000/213504...
#    Gescand: 170000/213504...
#    Gescand: 180000/213504...
#    Gescand: 190000/213504...
#    Gescand: 200000/213504...
#    Gescand: 210000/213504...
# ------------------------------
# Totaal GitHub fix-commits gevonden: 2053
#   Low: 135
#   Medium: 803
#   High: 771
#   Critical: 344

# %%
import math

def calculate_needed_sample(N, confidence_level=0.95, margin_of_error=0.10):
    """
    Berekent de steekproefgrootte n voor een populatie N.
    Standaard: 95% zekerheid, 10% foutmarge (om het haalbaar te houden voor mining).
    """
    if N == 0: return 0
    
    # Z-score voor 95% is 1.96
    Z = 1.96
    p = 0.5  # Worst-case schatting voor variantie (50%)
    e = margin_of_error
    
    # Formule van Cochran (aangepast voor eindige populatie)
    numerator = (Z**2 * p * (1-p)) / (e**2)
    n = numerator / (1 + ((numerator - 1) / N))
    
    return math.ceil(n)

# %%
if found_count == 0:
    print("Geen commits gevonden om te minen.")
else:
    to_mine = []
    print("\n--- STEEKPROEF BEREKENING (Stratified Sampling) ---")
    
    for g, urls in candidates.items():
        if urls:
            population_size = len(urls)
            
            # Hier berekenen we n specifiek voor DEZE groep
            needed_n = calculate_needed_sample(population_size, margin_of_error=0.10)
            
            # Veiligheidscheck: we kunnen niet meer minen dan we hebben
            # (Bijv. als formule 90 zegt, maar we hebben maar 50 links, pakken we er 50)
            final_n = min(len(urls), needed_n)
            
            print(f"Severity '{g}': Populatie={population_size} -> We minen er: {final_n}")
            
            # De daadwerkelijke loterij
            sample = random.sample(urls, final_n)
            for url in sample:
                to_mine.append({'group': g, 'url': url})

    print("-" * 40)
    print(f"Totaal te minen: {len(to_mine)} repositories.")
    print("-" * 40)
# Out:
# --- STEEKPROEF BEREKENING (Stratified Sampling) ---
# Severity 'Low': Populatie=135 -> We minen er: 57
# Severity 'Medium': Populatie=803 -> We minen er: 86
# Severity 'High': Populatie=771 -> We minen er: 86
# Severity 'Critical': Populatie=344 -> We minen er: 76
# ----------------------------------------
# Totaal te minen: 305 repositories.
# ----------------------------------------

# %%
results = []
    
    # Pas dit aan als je even wilt testen (bijv. to_mine[:5] voor een snelle check)
mining_queue = to_mine 

for idx, item in enumerate(mining_queue):
        # Voortgangsindicator
    if (idx + 1) % 5 == 0 or idx == 0: 
        print(f"[{idx+1}/{len(mining_queue)}] Mining: {item['url']} ({item['group']})")
        
    try:
        parts = item['url'].split('/commit/')
        repo_url = parts[0]
        commit_hash = parts[1]
            
        for commit in Repository(repo_url, single=commit_hash).traverse_commits():
            results.append({
                'severity': item['group'],
                'url': item['url'],
                'fix_date': commit.author_date, 
                'insertions': commit.insertions,
                'deletions': commit.deletions,
                'files_changed': commit.files,
                'churn': commit.insertions + commit.deletions
            })
    except Exception as e:
        # print(f"Fout bij {item['url']}: {e}") # Zet aan als je fouten wilt zien
        pass

print(f"\nKlaar! {len(results)} commits succesvol gemined.")
# Out:
# [1/305] Mining: https://github.com/micromatch/braces/commit/abdafb0cae1e0c00f184abbadc692f4eaa98f451 (Low)
# [5/305] Mining: https://github.com/wong2/mcp-cli/commit/35629664cc5d3aea4c3d083d075fe26e7c346b59 (Low)
# [10/305] Mining: https://github.com/indutny/elliptic/commit/34c853478cec1be4e37260ed2cb12cdbdc6402cf (Low)
# [15/305] Mining: https://github.com/senchalabs/connect/commit/126187c4e12162e231b87350740045e5bb06e93a (Low)
# [20/305] Mining: https://github.com/nodejs/undici/commit/2b39440bd9ded841c93dd72138f3b1763ae26055 (Low)
# [25/305] Mining: https://github.com/eslint/rewrite/commit/071be842f0bd58de4863cdf2ab86d60f49912abf (Low)
# [30/305] Mining: https://github.com/rejetto/hfs/commit/6531bcd2ab285af88f91831e30d8a03f5b9fe20d (Low)
# [35/305] Mining: https://github.com/directus/directus/commit/ef179931c55b50c110feca8404901d5633940771 (Low)
# [40/305] Mining: https://github.com/yhatt/jsx-slack/commit/36e4a10405e4c7745333e245fcc5029c02c7065d (Low)
# [45/305] Mining: https://github.com/nodejs/undici/commit/0a5bee9465e627be36bac88edf7d9bbc9626126d (Low)
# [50/305] Mining: https://github.com/Raynos/min-document/commit/fe32e8da464cef622528725f647029a8fd7d95a6 (Low)
# [55/305] Mining: https://github.com/npm/npm/commit/f4d31693 (Low)
# [60/305] Mining: https://github.com/nextauthjs/next-auth/commit/d16e04848ee703cf797724194d4ad2907fe125a9 (Medium)
# [65/305] Mining: https://github.com/mpetroff/pannellum/commit/cc2f3d99953de59db908e0c6efd1c2c17f7c6914 (Medium)
# [70/305] Mining: https://github.com/parse-community/parse-server/commit/37fed3062ccc3ef1dfd49a9fc53318e72b3e4aff (Medium)
# [75/305] Mining: https://github.com/getsentry/sentry-javascript/commit/35bdc87dee3498794e34c1ad35dd9927950c8766 (Medium)
# [80/305] Mining: https://github.com/DIYgod/RSSHub/commit/4671720f4c5e1aaaad8fcc1dce684b6546baf2ff (Medium)
# [85/305] Mining: https://github.com/electron/electron/commit/07a1c2a3e5845901f7e2eda9506695be58edc73c (Medium)
# [90/305] Mining: https://github.com/sequelize/sequelize/commit/c876192aa6ce1f67e22b26a4d175b8478615f42d (Medium)
# [95/305] Mining: https://github.com/nodejs/undici/commit/a29a151d0140d095742d21a004023d024fe93259 (Medium)
# [100/305] Mining: https://github.com/panva/jose/commit/03d6d013bf6e070e85adfe5731f526978e3e8e4d (Medium)
# [105/305] Mining: https://github.com/vitejs/vite/commit/62d7e81ee189d65899bb65f3263ddbd85247b647 (Medium)
# [110/305] Mining: https://github.com/artf/grapesjs/commit/13e85d152d486b968265c4b8017e8901e7d89ff3 (Medium)
# [115/305] Mining: https://github.com/sveltejs/svelte/commit/83e96e044deb5ecbae2af361ae9e31d3e1ac43a3 (Medium)
# [120/305] Mining: https://github.com/xmldom/xmldom/commit/d4201b9dfbf760049f457f9f08a3888d48835135 (Medium)
# [125/305] Mining: https://github.com/lunary-ai/lunary/commit/3451fcd7b9d95e9091d62c515752f39f2faa6e54 (Medium)
# [130/305] Mining: https://github.com/auth0/lock/commit/79ae557d331274b114848150f19832ae341771b1 (Medium)
# [135/305] Mining: https://github.com/claviska/jquery-minicolors/commit/ef134824a7f4110ada53ea6c173111a4fa2f48f3 (Medium)
# [140/305] Mining: https://github.com/jcubic/jquery.terminal/commit/c8b7727d21960031b62a4ef1ed52f3c634046211 (Medium)
# [145/305] Mining: https://github.com/ashaffer/cached-path-relative/commit/40c73bf70c58add5aec7d11e4f36b93d144bb760 (High)
# [150/305] Mining: https://github.com/better-auth/better-auth/commit/b381cac7aafd6aa53ef78b6ab771ebfa24643c80 (High)
# [155/305] Mining: https://github.com/lukeed/klona/commit/200e8d1fd383a54790ee6fc8228264c21954e38e (High)
# [160/305] Mining: https://github.com/browserify/browserify-sign/commit/85994cd6348b50f2fd1b73c54e20881416f44a30 (High)
# [165/305] Mining: https://github.com/directus/directus/commit/ce0397d16cf767b5293cd57f626c5349b5732a21 (High)
# [170/305] Mining: https://github.com/nodejs/undici/commit/f2324e549943f0b0937b09fb1c0c16cc7c93abdf (High)
# [175/305] Mining: https://github.com/chimurai/http-proxy-middleware/commit/0b4274e8cc9e9a2c5a06f35fbf456ccfcebc55a5 (High)
# [180/305] Mining: https://github.com/cryptocoinjs/secp256k1-node/commit/8bd6446e000fa59df3cda0ae3e424300747ea5ed (High)
# [185/305] Mining: https://github.com/ericcornelissen/shescape/commit/07a069a66423809cbedd61d980c11ca44a29ea2b (High)
# [190/305] Mining: https://github.com/n8n-io/n8n/commit/27adea70459329fc0dddabee69e10c9d1453835f (High)
# [195/305] Mining: https://github.com/ericcornelissen/shescape/commit/aceea7358f7222984e21260381ebc5ec4543b76f (High)
# [200/305] Mining: https://github.com/squirrellyjs/squirrelly/commit/426f930e5ca1501404cd887071e734ec5feb0bcf (High)
# [205/305] Mining: https://github.com/handlebars-lang/handlebars.js/commit/156061eb7707575293613d7fdf90e2bdaac029ee (High)
# [210/305] Mining: https://github.com/neocotic/convert-svg/commit/a43dffaab0f1e419d5be84e2e7356b86ffac3cf1 (High)
# [215/305] Mining: https://github.com/apostrophecms/sanitize-html/commit/b4682c12fd30e12e82fa2d9b766de91d7d2cd23c (High)
# [220/305] Mining: https://github.com/remix-run/react-router/commit/c84302972a152d851cf5dd859ff332b354b70111 (High)
# [225/305] Mining: https://github.com/robinweser/fast-loops/commit/6743acf64af832b7a0bbecf95cb4c7d95a3b766e (High)
# [230/305] Mining: https://github.com/NodeBB/NodeBB/commit/1783f918bc19568f421473824461ff2ed7755e4c (Critical)
# [235/305] Mining: https://github.com/strapi/strapi/commit/921d30961d6ba96cc098f2aea197350a49f990bd (Critical)
# [240/305] Mining: https://github.com/TooTallNate/plist.js/commit/96e2303d059e6be0c9e0c4773226d14b4758de52 (Critical)
# [245/305] Mining: https://github.com/angus-c/just/commit/dd57a476f4bb9d78c6f60741898dc04c71d2eb53 (Critical)
# [250/305] Mining: https://github.com/unshiftio/url-parse/commit/53b1794e54d0711ceb52505e0f74145270570d5a (Critical)
# [255/305] Mining: https://github.com/mysticatea/eslint-utils/commit/08158db1c98fd71cf0f32ddefbc147e2620e724c (Critical)
# [260/305] Mining: https://github.com/neocotic/convert-svg/commit/7e6031ac7427cf82cf312cb4a25040f2e6efe7a5 (Critical)
# [265/305] Mining: https://github.com/jaw187/node-traceroute/commit/b99ee024a01a40d3d20a92ad3769cc78a3f6386f (Critical)
# [270/305] Mining: https://github.com/github/hubot-scripts/commit/feee5abdb038a229a98969ae443cdb8a61747782 (Critical)
# [275/305] Mining: https://github.com/capricorn86/happy-dom/commit/5ee0b1676d4ce20cc2a70d1c9c8d6f1e3f57efac (Critical)
# [280/305] Mining: https://github.com/protobufjs/protobuf.js/commit/e66379f451b0393c27d87b37fa7d271619e16b0d (Critical)
# [285/305] Mining: https://github.com/handlebars-lang/handlebars.js/commit/f0589701698268578199be25285b2ebea1c1e427 (Critical)
# [290/305] Mining: https://github.com/eugeneware/changeset/commit/9e588844edbb9993b32e7366cc799262b4447f99 (Critical)
# [295/305] Mining: https://github.com/keystonejs/keystone/commit/65c6ee3deef23605fc72b80230908696a7a65e7c (Critical)
# [300/305] Mining: https://github.com/nuxt-modules/mdc/commit/99097738b5561639e9bf247c55d8103236618bf3 (Critical)
# [305/305] Mining: https://github.com/handlebars-lang/handlebars.js/commit/156061eb7707575293613d7fdf90e2bdaac029ee (Critical)
#
# Klaar! 292 commits succesvol gemined.

# %%
if results:
    df = pd.DataFrame(results)
    order = ['Low', 'Medium', 'High', 'Critical']
    
    print("\n" + "="*60)
    print(f"DETAIL ANALYSE FIXES: {ECOSYSTEM_NAME}")
    print("="*60)
    
    # We groeperen nu op severity en berekenen het gemiddelde van ALLES
    summary_table = df.groupby('severity')[['insertions', 'deletions', 'files_changed', 'churn']].mean().reindex(order)
    
    # Mooi printen (zonder decimalen voor regels code)
    print(summary_table.round(1))
    print("="*60)
    
    # --- PLOT 1: De Churn (zoals eerst) ---
    plt.figure(figsize=(10, 6))
    sns.stripplot(x='severity', y='churn', data=df, order=order, jitter=True, size=7, palette="Set2")
    plt.yscale('log') 
    plt.title(f'RQ2: Total Effort (Churn) - {ECOSYSTEM_NAME}')
    plt.ylabel('Lines of Code Changed (Log Scale)')
    plt.grid(axis='y', linestyle='--', alpha=0.3)
    plt.show()

    # --- PLOT 2 (NIEUW): Insertions vs Deletions ---
    # Dit laat zien: Wordt er vooral code geschreven (groen) of weggegooid (rood)?
    df_melt = df.melt(id_vars=['severity'], value_vars=['insertions', 'deletions'], var_name='Type', value_name='Lines')
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x='severity', y='Lines', hue='Type', data=df_melt, order=order, palette=['green', 'red'])
    plt.yscale('log')
    plt.title(f'RQ2: Type of Work (Add vs Delete) - {ECOSYSTEM_NAME}')
    plt.ylabel('Lines (Log Scale)')
    plt.show()

else:
    print("Geen data beschikbaar om te plotten.")
# Out:
# ============================================================
# DETAIL ANALYSE FIXES: Node.js (npm)
# ============================================================
#           insertions  deletions  files_changed   churn
# severity
# Low            804.1      364.9            8.4  1168.9
# Medium          82.2       16.3            4.6    98.4
# High           133.6       72.2            4.1   205.8
# Critical       225.6      102.1            5.8   327.8
# ============================================================
# /var/folders/s5/8b5j_kls30zg49cxlzy6rxl80000gn/T/ipykernel_18149/3629821572.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='severity', y='churn', data=df, order=order, jitter=True, size=7, palette="Set2")
